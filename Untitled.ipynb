# %%
#Various import
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np  
from scipy.signal import savgol_filter
from scipy.signal import find_peaks_cwt

from sklearn.preprocessing import normalize

# %%
#Load experimental data as dataframe
exp = pd.read_csv('Datasets/exp2_raw.csv', index_col=0)
exp_arr = exp.values
print(exp_arr.shape)

exp_arr = np.transpose(exp_arr)

norm = normalize(exp_arr,  axis=1, norm='l2')
print(norm.shape)
#print(norm)

for i in range(0, 24):
    plt.plot(norm[i,:])
    plt.xlim(0, 4000)
    plt.show()
# Out:
# (4249, 24)
# (24, 4249)

# %%
(w1,len1) = np.shape(exp_arr)
ndata = np.zeros([w1//2,len1])
for i in range(w1//2):
    ndata[:,:] = normalize(exp_arr[2*i+1,:], axis=1, norm='l2')
    
    
    

(len1,w1) = np.shape(exp_arr)
ndata = np.zeros([len1,w1//2])
#print(ndata.shape)
ndata2 = np.zeros([len1,w1//2])
for i in range(w1//2):
    #ndata[:,i] = (exp_arr[:,2*i+1]-min(exp_arr[:,2*i+1]))/(max(exp_arr[:,2*i+1])-min(exp_arr[:,2*i+1]))
    dumb = exp_arr.reshape(1, -1)
    #print(dumb.shape)
    ndata2 = normalize(dumb)
    #print(ndata2.shape)
    
plt.plot(norm[5,:])
plt.xlim(0, 4000)
plt.show()
# Out:
# (4249, 24)
# (24, 4249)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-63bb717c1ea3> in <module>
#      12 ndata = np.zeros([w1//2,len1])
#      13 for i in range(w1//2):
# ---> 14     ndata[:,:] = normalize(exp_arr[2*i+1,:], axis=1, norm='l2')
#      15
#      16
#
# c:\users\thibault\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\_data.py in normalize(X, norm, axis, copy, return_norm)
#    1703
#    1704     X = check_array(X, sparse_format, copy=copy,
# -> 1705                     estimator='the normalize function', dtype=FLOAT_DTYPES)
#    1706     if axis == 0:
#    1707         X = X.T
#
# ...

# %%
from ipynb.fs.full.autoXRD import normdata

#Load experimental data as dataframe
exp = pd.read_csv('Datasets/exp2.csv', index_col=0)
exp_arr = exp.values
print(exp_arr.shape)

nexp = normdata(exp_arr)

for i in range(0, 12):
    plt.plot(nexp[:,i])
    plt.xlim(0, 4000)
    plt.show()
# Out:
# (4249, 24)
